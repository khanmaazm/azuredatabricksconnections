# %%
import numpy as np
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Config for cosmosDB customer_master collection
sConfig = {
"Endpoint" : "https://aimindscosmosdb.documents.azure.com:443/",
"Masterkey" : "hN2IKLJ1wLlqqRN2Uiw56OyaJV5ZRPG3rKBLyVDVXv7VQCMoeOyCEnqliljCQmtx2xCgag3LR1a1ObNWiTAWlQ==",
"Database" : "advertisingcosmosdb",
"Collection" : "advertisingtable"
}

rdconnectionConfig = {
  "Endpoint" : "https://aimindscosmosdb.documents.azure.com:443/",
  "Masterkey" : "hN2IKLJ1wLlqqRN2Uiw56OyaJV5ZRPG3rKBLyVDVXv7VQCMoeOyCEnqliljCQmtx2xCgag3LR1a1ObNWiTAWlQ==",
  "Database" : "advertisingcosmosdb",
  "preferredRegions" : "West US 2",
  "Collection": "advertisingtable",
  "schema_samplesize" : "1000",
  "query_pagesize" : "200000",
  "query_custom" : "SELECT * FROM c"
}
print(sConfig)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;Endpoint&#39;: &#39;https://aimindscosmosdb.documents.azure.com:443/&#39;, &#39;Masterkey&#39;: &#39;hN2IKLJ1wLlqqRN2Uiw56OyaJV5ZRPG3rKBLyVDVXv7VQCMoeOyCEnqliljCQmtx2xCgag3LR1a1ObNWiTAWlQ==&#39;, &#39;Database&#39;: &#39;advertisingcosmosdb&#39;, &#39;Collection&#39;: &#39;advertisingtable&#39;}
# </div>

# %%
advertisingdf = spark.read.format("com.microsoft.azure.cosmosdb.spark").options(**rdconnectionConfig).load()
#users.createOrReplaceTempView("storm")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# ...

# %%
storage_account_name = "neonprodstorage"
storage_account_access_key = "="
sourcefilelocation = "wasbs://neon-prod-onetime@neonprodstorage.blob.core.windows.net/customer_master_org_stg/part-00020-tid-6005693990701974777-a347ceb6-519f-4dec-95e4-31bf93c7f212-789-c000.json"
spark.conf.set("fs.azure.account.key."+storage_account_name+".blob.core.windows.net",storage_account_access_key)
df_master_final= spark.read.json(sourcefilelocation)
#df_master_final.printSchema()

# %%
df_master_final.write.format("com.microsoft.azure.cosmosdb.spark").mode("overwrite").options(**sConfig).save()
